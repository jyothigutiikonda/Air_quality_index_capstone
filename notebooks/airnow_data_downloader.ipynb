# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from openpyxl import load_workbook

# %%
def append_to_file(new_df):
    file_path = "../data/AirData.xlsx"
    sheet_name = 'AirNow'

    book = load_workbook(file_path)
    sheet = book[sheet_name]
    startrow = sheet.max_row
    
    # Append without setting .book manually
    with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='overlay') as writer:
        new_df.to_excel(writer, sheet_name=sheet_name, startrow=startrow, index=False, header=False)

# %%
def process_data(url, date):
    print("Processing : " + url)
    air_df = pd.read_csv(url,sep = '|',header = None,
            names =['issuedate','validdate','time','timezone','record_sequence','datatype','primary','reporting_area','state_code','lat','lang','parameter_name','aqi_value','aqi_category','action_day','discussion','forecast_source'])
    airnow_data = air_df.drop(columns= ['issuedate','validdate', 'time','record_sequence', 'datatype','primary',
                                    'action_day','discussion', 'forecast_source'])
    airnow_data.dropna(inplace= True)
    airnow_data = airnow_data.drop(columns=['timezone','aqi_category'])
    airnow_data = airnow_data.loc[airnow_data.groupby(['reporting_area','parameter_name'])['aqi_value'].idxmax().values]
    air = airnow_data.pivot(index= ['reporting_area','state_code','lat','lang'],columns ='parameter_name',values= 'aqi_value').reset_index()
    air['CO'] = air['CO'].round().astype('Int64')
    air['NO2'] = air['NO2'].round().astype('Int64')
    air['OZONE'] = air['OZONE'].round().astype('Int64')
    air['PM10'] = air['PM10'].round().astype('Int64')
    air['PM2.5'] = air['PM2.5'].round().astype('Int64')
    air = air.drop(air.index[1:2])
    air = air[air.state_code.str.strip()!='']
    air = air.reset_index(drop = True)
    air['date'] = pd.to_datetime(date)
    air['date'] = pd.to_datetime(air['date'], format='%Y-%m-%d', errors='coerce')
    air['year'] = air['date'].dt.year
    air['month'] = air['date'].dt.month
    air['weekday'] = air['date'].dt.weekday
    air['month_name'] = air['date'].dt.strftime('%B')
    append_to_file(air)
    return air

# %%
for year in range(2019, 2025):
    for month in range(1, 13):
        if month < 10 :
            sMonth = "0"+str(month)
        else:
            sMonth = str(month)
        process_data("https://files.airnowtech.org/airnow/"+str(year)+"/"+str(year)+sMonth+"01/reportingarea.dat", str(year)+"-"+sMonth+"-01")
# Out:
# Processing : https://files.airnowtech.org/airnow/2019/20190101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20190201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20190301/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20190401/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20190501/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20190601/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20190701/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20190801/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20190901/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20191001/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20191101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2019/20191201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200301/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200401/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200501/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200601/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200701/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200801/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20200901/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20201001/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20201101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2020/20201201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210301/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210401/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210501/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210601/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210701/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210801/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20210901/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20211001/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20211101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2021/20211201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220301/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220401/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220501/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220601/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220701/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220801/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20220901/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20221001/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20221101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2022/20221201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230301/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230401/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230501/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230601/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230701/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230801/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20230901/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20231001/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20231101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2023/20231201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240201/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240301/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240401/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240501/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240601/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240701/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240801/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20240901/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20241001/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20241101/reportingarea.dat
# Processing : https://files.airnowtech.org/airnow/2024/20241201/reportingarea.dat
