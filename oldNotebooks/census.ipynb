# %%
import requests
import re
import json
from datetime import datetime

url = "https://www.macrotrends.net/production/global_metrics/city_state_pop_data.php?citystate=22956&slug=population&chart=chart1"

# Add browser headers
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/115.0.0.0 Safari/537.36",
    "Referer": "https://www.macrotrends.net/"
}

resp = requests.get(url, headers=headers)
resp.raise_for_status()
html = resp.text
data = json.loads(html)
last_6_entries = data['data'][-6:]
print(last_6_entries)
last_6_entries[0]

print(data['metadata']['tableHeaderName'])
# Out:
# [[1577836800000, 8865000], [1609459200000, 8877000], [1640995200000, 8901000], [1672531200000, 8937000], [1704067200000, 8984000], [1735689600000, 9042000]]
# Chicago Population

# %%
url = "https://www.macrotrends.net/production/global_metrics/city_state_pop_data.php?citystate=22956&slug=population&chart=chart1"

# Add browser headers
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/115.0.0.0 Safari/537.36",
    "Referer": "https://www.macrotrends.net/"
}

resp = requests.get(url, headers=headers)
resp.raise_for_status()
html = resp.text
data = json.loads(html)
last_6_entries = data['data'][-6:]
print(last_6_entries)
last_6_entries[0]

print(data['metadata']['tableHeaderName'])

# %%
def get_city_population_data(city_id: int):
    """
    Fetch population data from Macrotrends for a given city ID.
    """
    url = f"https://www.macrotrends.net/production/global_metrics/city_state_pop_data.php?citystate={city_id}&slug=population&chart=chart1"
    
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Referer": "https://www.macrotrends.net/"
    }

    response = requests.get(url, headers=headers)
    response.raise_for_status()
    data = json.loads(response.text)

    return {
        "city_name": data['metadata']['tableHeaderName'],
        "last_6_years": data['data'][-6:]  # Most recent 6 entries
    }
city_ids = {'Atlanta,GA':22922,
'Birmingham,AL':22936,
'Charleston,SC':22952,
'Chattanooga,TN':22955,
'Cleveland,MS':22959,
'Columbia,SC':22962,
'Huntsville,AL':23016,
'Knoxville,TN':23032,
'Little Rock-North Little Rock, AR':23049 ,
'Louisville,KY':23053,
'Memphis,TN':23063,
'Nashville,TN':23077,
'Myrtle Beach Conway,SC':23455,
'Richmond,VA':23115,
'Columbia,SC':22962,
'Savannah,GA':23137,
'Mobile,AL':23069,
'Kansas City,MO':23028,
'Springfield,MO':23150,
'Jackson, MS':23019}
records =[]
for city, city_id in city_ids.items():
    try:
        city_data = get_city_population_data(city_id)
        print(f"\n📍 City: {city_data['city_name']}")
        print("Last 6 years of population data:")
        for entry in city_data['last_6_years']:
            timestamp_ms = int(entry[0])  # Unix timestamp in milliseconds
            dt = datetime.fromtimestamp(timestamp_ms / 1000)
            formatted_date = dt.strftime("%Y-%m-%d")  # e.g., 2020-01-01
            population = entry[1]
            print(f"Date: {formatted_date} | Population: {population}")
    except Exception as e:
        print(f"⚠️ Error fetching data for {city}: {e}")
df = pd.DataFrame(records)
type(df)
# Out:
# 📍 City: Atlanta Population
# Last 6 years of population data:
# Date: 2019-12-31 | Population: 5803000
# Date: 2020-12-31 | Population: 5911000
# Date: 2021-12-31 | Population: 6013000
# Date: 2022-12-31 | Population: 6106000
# Date: 2023-12-31 | Population: 6193000
# Date: 2024-12-31 | Population: 6272000
#
# 📍 City: Birmingham Population
# Last 6 years of population data:
# Date: 2019-12-31 | Population: 842000
# Date: 2020-12-31 | Population: 849000
# Date: 2021-12-31 | Population: 856000
# Date: 2022-12-31 | Population: 863000
# Date: 2023-12-31 | Population: 871000
# Date: 2024-12-31 | Population: 879000
#
# 📍 City: Charleston-North Charleston Population
# Last 6 years of population data:
# Date: 2019-12-31 | Population: 708000
# Date: 2020-12-31 | Population: 721000
# Date: 2021-12-31 | Population: 734000
# Date: 2022-12-31 | Population: 745000
# Date: 2023-12-31 | Population: 756000
# Date: 2024-12-31 | Population: 765000
#
# 📍 City: Chattanooga Population
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
